# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #  Домашнее задание
#
# ## *Продвинутая линейная алгебра*

# %% [markdown]
# ### Задание
# #### 1. Дан объект в 2d пространстве:

# %%
A = [[-100, -100, 1], 
     [-100, 100, 1], 
     [100, 100, 1], 
     [0, 0, 1], 
     [100, -100, 1], 
     [-100, -100, 1]]

A = np.array(A)
x = A[:, 0]
y = A[:, 1]

plt.plot(x, y)
plt.grid()
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %% [markdown]
# #### При помощи линейных отображений:
#
# #### ● Уменьшить объект в два раза
# #### ● Повернуть на 130 градусов
# #### ● Отразить объект относительно прямой y=x
# #### ● Вычислить определитель композиции преобразований (итоговой матрицы реализующей все три отображения)

# %%
# Уменьшить объект в два раза

# %%
B = A * 0.5
x = B[:, 0]
y = B[:, 1]

plt.plot(x, y)
plt.grid()
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
# Повернуть на 130 градусов

# %% [markdown]
# The two dimensional rotation matrix which rotates points in the xy plane anti-clockwise through an angle θ about the origin is
# ![image.png](attachment:image.png)
#
# <span style="color:green">*** comments for me, so as not to forget<span>

# %%
theta = np.radians(130)
c, s = np.cos(theta), np.sin(theta)
R = np.array(((c, -s, 0), 
              (s, c, 0),
              (0, 0, 1)))
print(R)
# Out:
# [[-0.64278761 -0.76604444  0.        ]
#  [ 0.76604444 -0.64278761  0.        ]
#  [ 0.          0.          1.        ]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P1 = np.matmul(A, R)
x = P1[:,0]
y = P1[:,1]

plt.plot(x, y)
plt.grid()
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
#  Отразить объект относительно прямой y=x

# %% [markdown]
# https://www.javatpoint.com/computer-graphics-reflection
#
# 4. Reflection about line y=x: The object may be reflected about line y = x with the help of following transformation matrix
# ![image.png](attachment:image.png)
#
# First of all, the object is rotated at 45°. The direction of rotation is clockwise. After it reflection is done concerning x-axis. The last step is the rotation of y=x back to its original position that is counterclockwise at 45°.

# %%
Y = np.array([[0,1,0], [1,0,0], [0,0,1]])

# %%
S = A @ Y
x = S[:,0]
y = S[:,1]

plt.plot(x, y)
plt.grid()
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
# Вычислить определитель композиции преобразований (итоговой матрицы реализующей все три отображения)

# %%
D = np.array([[1, 0. , 0. ], [0. , 1, 0. ], [0. , 0. , 1. ]])
x = D[:,0]
y = D[:,1]

plt.plot(x, y)
plt.grid()
plt.ylim([-1, 2])
plt.xlim([-1, 2])
# Out:
# (-1.0, 2.0)

# %%
flatted_input = [0.5, 0.5, 1]
D = np.diagflat(flatted_input)
D
# Out:
# array([[0.5, 0. , 0. ],
#        [0. , 0.5, 0. ],
#        [0. , 0. , 1. ]])

# %%
x = D[:,0]
y = D[:,1]

plt.plot(x, y)
plt.grid()
plt.ylim([-1, 1])
plt.xlim([-1, 1])
# Out:
# (-1.0, 1.0)

# %%
theta = np.radians(130)
c, s = np.cos(theta), np.sin(theta)
R = np.array(((c, -s, 0), 
              (s, c, 0),
              (0, 0, 1)))

# %%
S = np.array([[1,0,0], [0,-1,0], [0,0,1]])

# %%
res_matrix = D @ R @ S
res_matrix
# Out:
# array([[-0.3213938 ,  0.38302222,  0.        ],
#        [ 0.38302222,  0.3213938 ,  0.        ],
#        [ 0.        ,  0.        ,  1.        ]])

# %%
determinant = np.linalg.det(res_matrix)
determinant
# Out:
# -0.25000000000000006

# %%
x = res_matrix[:,0]
y = res_matrix[:,1]

plt.plot(x, y)
plt.grid()
plt.ylim([-1, 1])
plt.xlim([-1, 1])
# Out:
# (-1.0, 1.0)

# %% [markdown]
# #### 2. Решите систему уравнений, используя матричный подход
# ![image-2.png](attachment:image-2.png)

# %%
C = np.array([[1, 0, 1, 0], [-1, 1, -2, 1], [4, 0, 1, -2], [-4, 4, 0, 1]])

# %%
D = np.array([[2], [-2], [0], [5]])

# %%
np.linalg.solve(C, D)
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [1.]])

# %%
# Ответ:

x = 0
y = 1
z = 2
w = 1

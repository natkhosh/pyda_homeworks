# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #  Домашнее задание

# %% [markdown]
# ### Задание 1
#
# #### Монетку подбрасывают 15 раз, найдите вероятность выпадения простого числа орлов.

# %% [markdown]
# ##### Для решения задачи воспользуемся формулой Бернулли:
# ![image-2.png](attachment:image-2.png)

# %%
# количество подбрасываний монетки
n = 15

# %%
# Простые числа до 15
simple_values = [2, 3, 5, 7, 11, 13]

# %%
P = 0
for k in simple_values:
    C = math.factorial(n) / (math.factorial(k) * math.factorial(n - k))
    P += C * (0.5 ** n)

print(f"Вероятность выпадения простого числа орлов: {P:.2f} или {P:2.0%}")
# Out:
# Вероятность выпадения простого числа орлов: 0.35 или 35%

# %% [markdown]
# ### Задание 2
#
# #### Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
f1_1 = np.random.normal(loc=0.0, scale=1.0, size=(40000,))

# %%
f1_2 = np.random.normal(loc=4, scale=2, size=(10000))

# %%
f1_3 = np.random.normal(loc=8, scale=0.8, size=(500000))

# %%
f1_4 = np.random.normal(loc=10, scale=1.5, size=(40000))

# %%
f1_5 = np.random.normal(loc=13, scale=5, size=(40000))

# %%
plt.figure(figsize=(10,8))
h_f1_1 = plt.hist(f1_1, bins=50, density=True)
h_f1_2 = plt.hist(f1_2, bins=50, density=True)
h_f1_3 = plt.hist(f1_3, bins=50, density=True)
h_f1_4 = plt.hist(f1_4, bins=50, density=True)
h_f1_5 = plt.hist(f1_5, bins=50, density=True)

# %%
f2_1 = np.random.exponential(scale=1.0, size=(40000,))

# %%
f2_2 = np.random.exponential(scale=1.2, size=(40000,))

# %%
f2_3 = np.random.exponential(scale=1.5, size=(40000,))

# %%
f2_4 = np.random.exponential(scale=2.0, size=(40000,))

# %%
f2_5 = np.random.exponential(scale=2.5, size=(40000,))

# %%
plt.figure(figsize=(10,10))
h_f2_1 = plt.hist(f2_1, bins=100, density=True)
h_f2_2 = plt.hist(f2_2, bins=100, density=True)
h_f2_3 = plt.hist(f2_3, bins=100, density=True)
h_f2_4 = plt.hist(f2_4, bins=100, density=True)
h_f2_5 = plt.hist(f2_5, bins=100, density=True)

# %%
f3_1 = np.random.standard_t(1000, size=(4000,))
f3_2 = np.random.standard_t(500, size=(4000,))
f3_3 = np.random.standard_t(200, size=(4000,))
f3_4 = np.random.standard_t(100, size=(4000,))
f3_5 = np.random.standard_t(10, size=(4000,))

# %%
plt.figure(figsize=(10,10))
h_f3_1 = plt.hist(f3_1, bins=100, density=True)
h_f3_2 = plt.hist(f3_2, bins=100, density=True)
h_f3_3 = plt.hist(f3_3, bins=100, density=True)
h_f3_4 = plt.hist(f3_4, bins=100, density=True)
h_f3_5 = plt.hist(f3_5, bins=100, density=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
from sympy import diff, symbols, cos, sin

# %% [markdown]
# #  Домашнее задание

# %% [markdown]
# ### Задание
# #### 1. Вычислить значения первой и второй производной функции:
# ![image-2.png](attachment:image-2.png)
# #### В точке x = 1.

# %% [markdown]
# ![photo_2021-11-16_22-01-21.jpg](attachment:photo_2021-11-16_22-01-21.jpg)

# %%
x = sym.Symbol('x')

# %%
# Первая производная функции

diff_1 = sym.diff( x ** 5 + 4*sym.sin(2 * x) + sym.cos(3 * x +3))
diff_1
# Out:
# 5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x)

# %%
a = diff_1
a
# Out:
# 5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x)

# %%
# Вычисление значения первой производной функции в точке: х = 1

print(diff_1.subs(x, 1)) 
print(f'Значение первой производной функции в точке х = 1: => {(8 * np.cos(2) - 3 * np.sin(6)+5):.4f}')
# Out:
# 8*cos(2) - 3*sin(6) + 5
# Значение первой производной функции в точке х = 1: => 2.5091

# %%
# Второя производная функции

diff_2 = sym.diff(diff_1)
diff_2
# Out:
# 20*x**3 - 16*sin(2*x) - 9*cos(3*x + 3)

# %%
# Вычисление значения второй производной функции в точке: х = 1

print(diff_2.subs(x, 1)) 
print(f'Значение первой производной функции в точке х = 1: => {(-16 * np.sin(2) - 9 * np.cos(6) + 20):.4f}')
# Out:
# -16*sin(2) - 9*cos(6) + 20
# Значение первой производной функции в точке х = 1: => -3.1903

# %% [markdown]
# #### 2. Постройте график функции, первой и второй производной:
# ![image.png](attachment:image.png)
# #### На отрезке [-5; 5].

# %% [markdown]
# ![photo_2021-11-16_22-01-15.jpg](attachment:photo_2021-11-16_22-01-15.jpg)

# %%
x = sym.Symbol('x')

# %%
# Первая производная функции

diff_2_1 = sym.diff(sym.sin(2 * x + 1)**5)
diff_2_1
# Out:
# 10*sin(2*x + 1)**4*cos(2*x + 1)

# %%
# Второя производная функции

diff_2_2 = sym.diff(diff_2_1)
diff_2_2
# Out:
# -20*sin(2*x + 1)**5 + 80*sin(2*x + 1)**3*cos(2*x + 1)**2

# %%
# создаём массив данных для переменной х
X = np.linspace(-5, 5)
X
# Out:
# array([-5.        , -4.79591837, -4.59183673, -4.3877551 , -4.18367347,
#        -3.97959184, -3.7755102 , -3.57142857, -3.36734694, -3.16326531,
#        -2.95918367, -2.75510204, -2.55102041, -2.34693878, -2.14285714,
#        -1.93877551, -1.73469388, -1.53061224, -1.32653061, -1.12244898,
#        -0.91836735, -0.71428571, -0.51020408, -0.30612245, -0.10204082,
#         0.10204082,  0.30612245,  0.51020408,  0.71428571,  0.91836735,
#         1.12244898,  1.32653061,  1.53061224,  1.73469388,  1.93877551,
#         2.14285714,  2.34693878,  2.55102041,  2.75510204,  2.95918367,
#         3.16326531,  3.36734694,  3.57142857,  3.7755102 ,  3.97959184,
#         4.18367347,  4.3877551 ,  4.59183673,  4.79591837,  5.        ])

# %%
# строим график первой производной функции f(x)

# %%
def func_diff_2_1(x):
    return 10 * np.sin(2 * x + 1)** 4 * np.cos(2 * x + 1)

# %%
plt.plot(X, func_diff_2_1(X))
plt.xlabel("x = [-5, 5]")
plt.ylabel("f(x)")
plt.title('Первая производная f(x)')
plt.grid()
plt.show()

# %%
# строим график второй производной функции f(x)

# %%
def func_diff_2_2(x):
    return -20 * np.sin(2 * x + 1)** 5 + 80 * np.sin(2 * x + 1)** 3 * np.cos(2 * x + 1)** 2

# %%
plt.plot(X, func_diff_2_2(X))
plt.xlabel("x = [-5, 5]")
plt.ylabel("f(x)")
plt.title('Вторая производная f(x)')
plt.grid()
plt.show()

# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: `<дата> - <заголовок> - <ссылка> - <текст_статьи>`

# %%
import requests
import pandas as pd
import time
from bs4 import BeautifulSoup

# %%
KEYWORDS = ['python', 'парсинг']

URL = 'https://habr.com/ru/all/'

# %%
req = requests.get(URL)
soup = BeautifulSoup(req.text, 'html.parser')

# %%
#  Находим количество новостных страниц

num_pages = soup.find('div',class_="tm-pagination__pages").text
pages = [int(item) for item in num_pages.replace('...', '').split()]
last_page = pages[-1]
last_page
# Out:
# 50

# %%
#  Список ссылок на новостные страницы

list_urls = [str(URL + 'page'+ str(i)) for i in range(1, last_page+1)]
# list_urls

# %%
#  TEST: Тестовый список ссылок на новостные страницы
list_urls = [str(URL + 'page'+ str(i)) for i in range(1, 17)]
list_urls
# Out:
# ['https://habr.com/ru/all/page1',
#  'https://habr.com/ru/all/page2',
#  'https://habr.com/ru/all/page3',
#  'https://habr.com/ru/all/page4',
#  'https://habr.com/ru/all/page5',
#  'https://habr.com/ru/all/page6',
#  'https://habr.com/ru/all/page7',
#  'https://habr.com/ru/all/page8',
#  'https://habr.com/ru/all/page9',
#  'https://habr.com/ru/all/page10',
#  'https://habr.com/ru/all/page11',
#  'https://habr.com/ru/all/page12',
#  'https://habr.com/ru/all/page13',
#  'https://habr.com/ru/all/page14',
#  'https://habr.com/ru/all/page15',
#  'https://habr.com/ru/all/page16']

# %% [markdown]
# ##### Вариант 1

# %%
def get_all_links(urls):
    """
    Функция получения ссылок на полные статьи по всем страницам новостей
    page number = 50
    """
    all_refs = []
    for url in urls: 
        res = requests.get(url)
        soup = BeautifulSoup(res.text, 'html.parser')

        time.sleep(0.3)

        posts = soup.find_all('article', class_='tm-articles-list__item')
        post_h2 = set()
        post_h3 = set()


        if soup.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2'):
            post_h2 = set(map(lambda x: x.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2'), posts))
            if None in post_h2:
                post_h2.remove(None)

        if soup.find('div', class_='tm-megapost-snippet__tint'):
            post_h3 = set(map(lambda x: x.find('div', class_='tm-megapost-snippet'), posts))
            if None in post_h3:
                post_h3.remove(None)

        posts_list = list(post_h2) + list(post_h3)
        post_link = list(map(lambda x: x.find('a').get('href'), posts_list))
        link_list = list(map(lambda x: 'https://habr.com' + x, post_link))
        all_refs +=link_list

    return all_refs

# %%
def get_news_table(links):
     """
    Поиск новостей, в которых встречается хотя бы одно требуемое ключевое слово из KEYWORDS,
    по всей доступной preview-информации
    """
    news_ = pd.DataFrame()
    for link in links:
        soup = BeautifulSoup(requests.get(link).text, 'html.parser')
        time.sleep(0.3)
        
        text = soup.find('div', class_='article-formatted-body').text.lower()

        for word in KEYWORDS:
            if word in text:
                date = pd.to_datetime(soup.find('span', class_='tm-article-snippet__datetime-published').find('time').get('datetime'), dayfirst=True)
                title = soup.find('h1', class_='tm-article-snippet__title').text

                row = {'date': date, 'title': title, 'link': link, 'text': text}
                news_ = pd.concat([news_, pd.DataFrame([row])])
                # Прекращаем парсить статью, если обнаружено ключевое слово. Предотвращение создания дубликатов
                break

    news_table = news_.reset_index()
    news_table.drop('index', axis=1, inplace=True)
    return news_table

# %%
get_news_table(get_all_links(list_urls))
# Out:
#                         date  \
# 0  2021-08-05 12:12:11+00:00
# 1  2021-08-05 10:54:22+00:00
# 2  2021-08-05 10:12:10+00:00
# 3  2021-08-05 07:40:02+00:00
# 4  2021-08-05 05:11:33+00:00
# 5  2021-08-05 05:18:28+00:00
# 6  2021-08-05 08:05:38+00:00
# 7  2021-08-04 16:40:44+00:00
# 8  2021-08-04 15:14:11+00:00
# 9  2021-08-04 15:36:23+00:00
# 10 2021-08-04 17:19:39+00:00
# 11 2021-08-04 11:00:43+00:00
# 12 2021-08-04 11:04:01+00:00
# 13 2021-08-04 11:59:48+00:00
# 14 2021-08-04 06:21:39+00:00
# 15 2021-08-04 05:21:58+00:00
# 16 2021-08-04 04:50:16+00:00
# 17 2021-08-03 20:47:06+00:00
# 18 2021-08-03 17:14:17+00:00
# 19 2021-08-03 16:25:48+00:00
# 20 2021-08-03 11:46:04+00:00
# 21 2021-08-03 13:14:43+00:00
# 22 2021-08-03 11:44:36+00:00
# 23 2021-08-03 13:46:10+00:00
# 24 2021-08-03 11:54:01+00:00
# 25 2021-08-03 11:00:02+00:00
# 26 2021-08-03 08:00:03+00:00
# 27 2021-08-03 09:11:18+00:00
# 28 2021-08-03 09:00:01+00:00
# 29 2021-08-03 07:15:01+00:00
# 30 2021-08-03 07:58:28+00:00
# 31 2021-08-03 08:00:01+00:00
# 32 2021-08-02 15:38:38+00:00
# 33 2021-08-03 05:02:28+00:00
# 34 2021-08-02 15:55:29+00:00
# 35 2021-08-02 15:04:37+00:00
# 36 2021-08-02 14:22:22+00:00
# 37 2021-08-02 12:03:46+00:00
# 38 2021-08-02 11:22:06+00:00
# 39 2021-08-02 14:48:19+00:00
# 40 2021-08-02 14:38:04+00:00
# 41 2021-08-02 10:14:52+00:00
# 42 2021-08-02 09:13:04+00:00
# 43 2021-08-02 06:58:01+00:00
# 44 2021-08-01 17:48:35+00:00
# 45 2021-08-02 07:00:02+00:00
# 46 2021-08-01 17:34:10+00:00
# 47 2021-08-01 16:24:05+00:00
# 48 2021-08-01 11:12:39+00:00
# 49 2021-07-31 11:31:48+00:00
# 50 2021-07-31 18:06:29+00:00
# 51 2021-07-31 15:18:51+00:00
# 52 2021-07-30 13:00:02+00:00
# 53 2021-07-30 14:47:36+00:00
# 54 2021-07-30 14:39:28+00:00
# 55 2021-07-30 10:58:13+00:00
# 56 2021-07-30 06:59:40+00:00
# 57 2021-07-30 08:01:14+00:00
# 58 2021-07-30 08:00:03+00:00
# 59 2021-07-30 10:47:18+00:00
#
#                                                 title  \
# 0   Интеграция поисковой машины Яндекса с сайтом. ...
# 1   Трек DeepPavlov в онлайн-школе Community of Op...
# 2                    Где работать в ИТ в 2021: GigAnt
# 3   Приглашаем компании к спонсорcтву PyCon Russia...
# 4   История одного фееричного провала тестового за...
# 5   Спектральный анализ временных рядов с помощью ...
# 6   Ускоряем код на Питоне с помощью расширений на Cи
# 7          Разбираемся с ChainMap из коллекций Python
# 8   Формируем реляционную модель из schemaless баз...
# 9               Ансамблевые методы машинного обучения
# 10  ROS: стань контрибьютором самого большого Open...
# 11  Как количественные исследования помогают созда...
# 12                        Как собрать свой Lighthouse
# 13  [Личный опыт] Жизнь и IT в Сеуле: почему жить ...
# 14  Как совместить поездку на конференцию и семейн...
# 15  Использование паттерна BFF для создания общих ...
# 16                 Миграция с Terraform на Terragrunt
# 17            Разбираем обфусцированный CrackMe на C#
# 18  Лучшие RP2040 платы для ваших проектов в 2021 ...
# 19             Как сделать магический шар на Three.js
# 20  Всё о работе с cookie в Python — класс http.co...
# 21  Приглашаем в онлайн-школу Open Source-разработ...
# 22                Гайд по использованию enum в Python
# 23        Начинал строить дома, построил карьеру в IT
# 24            Еще один сайт для изучения слов. Зачем?
# 25  Почему у нас такое жёсткое лицензионное соглаш...
# 26  Marshmallow vs. Pydantic: две лучшие библиотек...
# 27    Greybox-фаззинг: level up. Как улучшали фаззеры
# 28  Do IT like a Russian: чем крупный ритейл может...
# 29  Киберпанк, который мы заслужили, или как Prism...
# 30  Структурная нота: кому — вершки, а кому — коре...
# 31                          BDD-тестирование чат-бота
# 32  Infrastructure as code: обзор опенсорсных инст...
# 33  Clickhouse рядом с Zabbix или чем собирать лог...
# 34  Обзор Codelobster — Удобная кроссплатформенная...
# 35           Property-based тестирование с QuickCheck
# 36   Профессионально обрабатываем исключения в Python
# 37               Распознавание блюд в кафетерии банка
# 38  Метеостанция на Banana Pi M64 (Linux, C#, Dock...
# 39               От мюонного соленоида к Data Science
# 40  Нейродайджест: главное из области машинного об...
# 41  Кратко: запросы к API и разбор XML-ответов. Py...
# 42  Немного про современные технологии Greybox-фаз...
# 43                   10 приниципов разработки на Java
# 44  FOSS News №81 – дайджест материалов о свободно...
# 45  Еще одна стажировка, или сказ про реверс IP-ка...
# 46  Чем машинное обучение отличается от статистики...
# 47  Установка JUNIPER VRR через CLI на гипервизоре...
# 48  Когда нужна телеметрия: интегрируем в проект б...
# 49  [Личный опыт] Лондон: не всегда мечта для прог...
# 50  Три предметно-ориентированных языка программир...
# 51    Tweet-a-pot, или Как я через Twitter кофе варил
# 52      С Днём Сисадмина! А кто его сегодня отмечает?
# 53  Где ещё жить и работать кроме Москвы: четыре г...
# 54    Как перенести нейросеть на мобильное устройство
# 55  13 проектов для Python-программистов уровня in...
# 56          Выявление самозванцев среди программистов
# 57           Opensource система умного дома на nodejs
# 58  3 совета для разработчиков по результатам 20 с...
# 59                     Миру нужны фуллстек-крафтсмены
#
#                                                  link  \
# 0                    https://habr.com/ru/post/571428/
# 1    https://habr.com/ru/company/samsung/blog/571404/
# 2   https://habr.com/ru/company/habr_career/blog/5...
# 3   https://habr.com/ru/company/it_people/blog/571...
# 4                    https://habr.com/ru/post/571342/
# 5                    https://habr.com/ru/post/571344/
# 6   https://habr.com/ru/company/alconost/blog/571366/
# 7   https://habr.com/ru/company/skillfactory/blog/...
# 8       https://habr.com/ru/company/otus/blog/571286/
# 9                    https://habr.com/ru/post/571296/
# 10   https://habr.com/ru/company/samsung/blog/571302/
# 11  https://habr.com/ru/company/ncloudtech/blog/56...
# 12  https://habr.com/ru/company/oleg-bunin/blog/57...
# 13       https://habr.com/ru/company/gms/blog/571234/
# 14  https://habr.com/ru/company/it_people/blog/571...
# 15    https://habr.com/ru/company/itsoft/blog/571004/
# 16  https://habr.com/ru/company/southbridge/blog/5...
# 17                   https://habr.com/ru/post/571134/
# 18  https://habr.com/ru/company/selectel/blog/570018/
# 19  https://habr.com/ru/company/skillfactory/blog/...
# 20   https://habr.com/ru/company/timeweb/blog/564620/
# 21   https://habr.com/ru/company/samsung/blog/570952/
# 22   https://habr.com/ru/company/timeweb/blog/564826/
# 23    https://habr.com/ru/company/kolesa/blog/571074/
# 24                   https://habr.com/ru/post/570504/
# 25     https://habr.com/ru/company/ruvds/blog/571010/
# 26  https://habr.com/ru/company/domclick/blog/570802/
# 27    https://habr.com/ru/company/bizone/blog/570534/
# 28    https://habr.com/ru/company/magnit/blog/570992/
# 29    https://habr.com/ru/company/prisma/blog/559028/
# 30                   https://habr.com/ru/post/570900/
# 31  https://habr.com/ru/company/oleg-bunin/blog/55...
# 32      https://habr.com/ru/company/otus/blog/570926/
# 33                   https://habr.com/ru/post/570958/
# 34                   https://habr.com/ru/post/568620/
# 35  https://habr.com/ru/company/typeable/blog/570922/
# 36      https://habr.com/ru/company/otus/blog/570882/
# 37      https://habr.com/ru/company/alfa/blog/569208/
# 38   https://habr.com/ru/company/timeweb/blog/569748/
# 39  https://habr.com/ru/company/skillfactory/blog/...
# 40                   https://habr.com/ru/post/570912/
# 41                   https://habr.com/ru/post/570852/
# 42    https://habr.com/ru/company/bizone/blog/570312/
# 43                   https://habr.com/ru/post/570654/
# 44                   https://habr.com/ru/post/570764/
# 45  https://habr.com/ru/company/ntc-vulkan/blog/56...
# 46  https://habr.com/ru/company/skillfactory/blog/...
# 47                   https://habr.com/ru/post/570752/
# 48                   https://habr.com/ru/post/570720/
# 49       https://habr.com/ru/company/gms/blog/570652/
# 50  https://habr.com/ru/company/audiomania/blog/57...
# 51  https://habr.com/ru/company/skillfactory/blog/...
# 52     https://habr.com/ru/company/ruvds/blog/570418/
# 53   https://habr.com/ru/company/headzio/blog/570506/
# 54                   https://habr.com/ru/post/570052/
# 55  https://habr.com/ru/company/skillbox/blog/570472/
# 56                   https://habr.com/ru/post/570198/
# 57                   https://habr.com/ru/post/570432/
# 58                   https://habr.com/ru/post/570430/
# 59     https://habr.com/ru/company/jugru/blog/558702/
#
#                                                  text
# 0   за 3 месяца сразу 2 клиента интерволги (интерн...
# 1   лето подходит к концу, а возможность поработат...
# 2   сегодня в рубрике «где работать в ит» расскаже...
# 3   если спросить опытного питониста в каких компа...
# 4   просидев на одном предприятии несколько лет, я...
# 5   с развитием информационных технологий професси...
# 6   производительность си — в программах на питоне...
# 7   chainmap — инструмент управления поиском в сло...
# 8   mongodb – одна из самых популярных документ-ор...
# 9   ансамблевые методы - это мощный инструмент для...
# 10  источник: https://spectrum.ieee.org/automaton/...
# 11  количественные методы ux-исследований —  такие...
# 12  чем интенсивнее наш feature delivering, тем бы...
# 13  недавно мы рассказывали о жизни разработчика в...
# 14  мы (it-people) уже 11 лет проводим конференции...
# 15  \r\nконтракт между бэкендным сервисом и фронте...
# 16  https://miro.medium.com/max/700/1*fnd69vqapyso...
# 17  имеется файл crackme, при запуске которого пре...
# 18  \n\r\nв январе 2021 года raspberry foundation ...
# 19  анимированный объём при помощи встроенного шей...
# 20   \nмодуль http.cookies реализует парсер для co...
# 21  открытое программное обеспечение (open source ...
# 22  \nмодуль enum содержит в себе тип для перечисл...
# 23  часто слышу мнение, что для работы программист...
# 24  я пробовал anki, cram, memrise, drops, quizlet...
# 25  \n\nпервый конфликт — в том, чтобы дать клиент...
# 26  сериализация и десериализация данных — это пре...
# 27  \nавтор: иннокентий сенновский \nв предыдущей ...
# 28  привет! меня зовут валентин щитов, я cio компа...
# 29  привет, хабр! я миша, r&d инженер в prisma lab...
# 30  лирическое вступлениекадр из мультфильма 1974 ...
# 31  многие знакомы с методологией test-driven deve...
# 32  давайте взглянем на текущее положение вещей в ...
# 33  если вы используете zabbix для мониторинга ваш...
# 34  раньше, когда еще не было ни phpstorm-а, ни vs...
# 35  автор статьи: klntsky \n\nчто такое property-b...
# 36  одним из недостатков гибких языков, таких как ...
# 37  в кафетерии альфа-банка в обеденный час-пик об...
# 38  \n\r\nстатей о создании метеостанции на базе a...
# 39  компактный мюонный соленоид в пещереавтор стат...
# 40  новый язык программирования от open ai, рост п...
# 41  этот пост предназначен в первую очередь для но...
# 42  \nавтор: иннокентий сенновский\nкак найти баги...
# 43  сколько раз вы были в ситуации, когда вы хотел...
# 44  \n\nвсем привет!\nпродолжаем дайджесты новосте...
# 45  вступлениеитак, меня взяли на стажировку. стаж...
# 46  к старту курса о машинном и глубоком обучении ...
# 47  в определенный момент домашняя лаба (бесшумная...
# 48  два сигнала телеметрии, формируемые в микрокон...
# 49  анатолий бардуков работал в «яндексе», улучшая...
# 50  в прошлый раз мы рассказывали о книгах, которы...
# 51  мы уже писали о том, как сделать умный термост...
# 52  профессию сисадмина пытались забыть несколько ...
# 53  в москве есть практически всё: есть где порабо...
# 54  в статье поговорим как обучить несложную cnn с...
# 55  изучение основ python — прекрасный опыт. но эй...
# 56  кратко о себе. работаю в центральном аппарате ...
# 57  интерфейс главного менюпривет, хабр! хочу поде...
# 58  на глаза попалась статья о приеме разработчико...
# 59   \nспор «фуллстек против узкой специализации» ...

# %%
d = get_news_table(get_all_links(list_urls))
d[['text']]
# Out:
#                                                  text
# 0   за 3 месяца сразу 2 клиента интерволги (интерн...
# 1   лето подходит к концу, а возможность поработат...
# 2   сегодня в рубрике «где работать в ит» расскаже...
# 3   если спросить опытного питониста в каких компа...
# 4   просидев на одном предприятии несколько лет, я...
# 5   с развитием информационных технологий професси...
# 6   производительность си — в программах на питоне...
# 7   chainmap — инструмент управления поиском в сло...
# 8   mongodb – одна из самых популярных документ-ор...
# 9   ансамблевые методы - это мощный инструмент для...
# 10  источник: https://spectrum.ieee.org/automaton/...
# 11  количественные методы ux-исследований —  такие...
# 12  чем интенсивнее наш feature delivering, тем бы...
# 13  недавно мы рассказывали о жизни разработчика в...
# 14  \r\nконтракт между бэкендным сервисом и фронте...
# 15  https://miro.medium.com/max/700/1*fnd69vqapyso...
# 16  имеется файл crackme, при запуске которого пре...
# 17  \n\r\nв январе 2021 года raspberry foundation ...
# 18  анимированный объём при помощи встроенного шей...
# 19  мы (it-people) уже 11 лет проводим конференции...
# 20   \nмодуль http.cookies реализует парсер для co...
# 21  открытое программное обеспечение (open source ...
# 22  \nмодуль enum содержит в себе тип для перечисл...
# 23  часто слышу мнение, что для работы программист...
# 24  я пробовал anki, cram, memrise, drops, quizlet...
# 25  сериализация и десериализация данных — это пре...
# 26  \nавтор: иннокентий сенновский \nв предыдущей ...
# 27  привет! меня зовут валентин щитов, я cio компа...
# 28  привет, хабр! я миша, r&d инженер в prisma lab...
# 29  лирическое вступлениекадр из мультфильма 1974 ...
# 30  \n\nпервый конфликт — в том, чтобы дать клиент...
# 31  многие знакомы с методологией test-driven deve...
# 32  давайте взглянем на текущее положение вещей в ...
# 33  если вы используете zabbix для мониторинга ваш...
# 34  раньше, когда еще не было ни phpstorm-а, ни vs...
# 35  одним из недостатков гибких языков, таких как ...
# 36  в кафетерии альфа-банка в обеденный час-пик об...
# 37  компактный мюонный соленоид в пещереавтор стат...
# 38  новый язык программирования от open ai, рост п...
# 39  автор статьи: klntsky \n\nчто такое property-b...
# 40  этот пост предназначен в первую очередь для но...
# 41  \n\r\nстатей о создании метеостанции на базе a...
# 42  \nавтор: иннокентий сенновский\nкак найти баги...
# 43  сколько раз вы были в ситуации, когда вы хотел...
# 44  \n\nвсем привет!\nпродолжаем дайджесты новосте...
# 45  вступлениеитак, меня взяли на стажировку. стаж...
# 46  к старту курса о машинном и глубоком обучении ...
# 47  в определенный момент домашняя лаба (бесшумная...
# 48  два сигнала телеметрии, формируемые в микрокон...
# 49  анатолий бардуков работал в «яндексе», улучшая...
# 50  в прошлый раз мы рассказывали о книгах, которы...
# 51  мы уже писали о том, как сделать умный термост...
# 52  профессию сисадмина пытались забыть несколько ...
# 53  в москве есть практически всё: есть где порабо...
# 54  в статье поговорим как обучить несложную cnn с...
# 55  изучение основ python — прекрасный опыт. но эй...
# 56  кратко о себе. работаю в центральном аппарате ...
# 57  интерфейс главного менюпривет, хабр! хочу поде...
# 58  на глаза попалась статья о приеме разработчико...
# 59   \nспор «фуллстек против узкой специализации» ...

# %% [markdown]
# ## Вариант 2:
# Тестирование ошибок:
# - AttributeError: 'NoneType' object has no attribute 'text' - 20 страница последний пост https://habr.com/ru/company/kingston_technology/blog/569952/

# %%
list_urls = [str(URL + 'page'+ str(i)) for i in range(1, last_page+1)]

# list_urls

# %%
list_urls = [str(URL + 'page'+ str(i)) for i in range(20, 21)]

# (list_urls)

# %%
def get_all_links(urls):
    """
    Функция получения ссылок на полные статьи на 
    """ 
    all_refs = []
    
    for url in urls: 
        res = requests.get(url)
        soup = BeautifulSoup(res.text, 'html.parser')

        time.sleep(0.3)

        posts = soup.find_all('article', class_='tm-articles-list__item')
        post_h2 = set()
        post_h3 = set()


        if soup.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2'):
            post_h2 = set(map(lambda x: x.find('h2', class_='tm-article-snippet__title tm-article-snippet__title_h2'), posts))
            if None in post_h2:
                post_h2.remove(None)

        if soup.find('div', class_='tm-megapost-snippet__tint'):
            post_h3 = set(map(lambda x: x.find('div', class_='tm-megapost-snippet'), posts))
            if None in post_h3:
                post_h3.remove(None)

        posts_list = list(post_h2) + list(post_h3)
        post_link = list(map(lambda x: x.find('a').get('href'), posts_list))
        link_list = list(map(lambda x: 'https://habr.com' + x, post_link))
        all_refs +=link_list
        
    return all_refs

# %%
def get_news_table(links):
    news_ = pd.DataFrame()
    
    for link in links:
        soup = BeautifulSoup(requests.get(link).text, 'html.parser')
        time.sleep(0.3)
        
        text = soup.find(class_='article-formatted-body').text.lower()

        for word in KEYWORDS:
            if word in text:
                date = pd.to_datetime(soup.find('span', class_='tm-article-snippet__datetime-published').find('time').get('datetime'), dayfirst=True)
                title = soup.find('h1', class_='tm-article-snippet__title').text

                row = {'date': date, 'title': title, 'link': link, 'text': text}
                news_ = pd.concat([news_, pd.DataFrame([row])])
                # Прекращаем парсить статью, если обнаружено ключевое слово. Предотвращение создания дубликатов
                break

    news_table = news_.reset_index()
    news_table.drop('index', axis=1, inplace=True)
    return news_table

# %%
# Pages 20
get_news_table(get_all_links(list_urls))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-804-efb5c0d40ade> in <module>
#       1 # Pages 20
# ----> 2 get_news_table(get_all_links(list_urls))
#
# <ipython-input-803-b92bfe013d44> in get_news_table(links)
#       6         time.sleep(0.3)
#       7
# ----> 8         text = soup.find(class_='article-formatted-body').text.lower()
#       9
#      10         for word in KEYWORDS:
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Pages 1-10
get_news_table(get_all_links(list_urls))
# Out:
#                         date  \
# 0  2021-08-05 12:12:11+00:00
# 1  2021-08-05 10:54:22+00:00
# 2  2021-08-05 10:12:10+00:00
# 3  2021-08-05 07:40:02+00:00
# 4  2021-08-05 05:11:33+00:00
# 5  2021-08-05 05:18:28+00:00
# 6  2021-08-05 08:05:38+00:00
# 7  2021-08-04 16:40:44+00:00
# 8  2021-08-04 15:14:11+00:00
# 9  2021-08-04 15:36:23+00:00
# 10 2021-08-04 17:19:39+00:00
# 11 2021-08-04 11:00:43+00:00
# 12 2021-08-04 11:04:01+00:00
# 13 2021-08-04 11:59:48+00:00
# 14 2021-08-04 05:21:58+00:00
# 15 2021-08-04 04:50:16+00:00
# 16 2021-08-03 20:47:06+00:00
# 17 2021-08-03 17:14:17+00:00
# 18 2021-08-04 06:21:39+00:00
# 19 2021-08-03 11:46:04+00:00
# 20 2021-08-03 13:14:43+00:00
# 21 2021-08-03 11:44:36+00:00
# 22 2021-08-03 13:46:10+00:00
# 23 2021-08-03 16:25:48+00:00
# 24 2021-08-03 11:54:01+00:00
# 25 2021-08-03 08:00:03+00:00
# 26 2021-08-03 09:11:18+00:00
# 27 2021-08-03 09:00:01+00:00
# 28 2021-08-03 07:58:28+00:00
# 29 2021-08-03 11:00:02+00:00
# 30 2021-08-03 08:00:01+00:00
# 31 2021-08-03 05:02:28+00:00
# 32 2021-08-03 07:15:01+00:00
# 33 2021-08-02 15:55:29+00:00
# 34 2021-08-02 15:38:38+00:00
# 35 2021-08-02 14:22:22+00:00
# 36 2021-08-02 14:48:19+00:00
# 37 2021-08-02 14:38:04+00:00
# 38 2021-08-02 15:04:37+00:00
#
#                                                 title  \
# 0   Интеграция поисковой машины Яндекса с сайтом. ...
# 1   Трек DeepPavlov в онлайн-школе Community of Op...
# 2                    Где работать в ИТ в 2021: GigAnt
# 3   Приглашаем компании к спонсорcтву PyCon Russia...
# 4   История одного фееричного провала тестового за...
# 5   Спектральный анализ временных рядов с помощью ...
# 6   Ускоряем код на Питоне с помощью расширений на Cи
# 7          Разбираемся с ChainMap из коллекций Python
# 8   Формируем реляционную модель из schemaless баз...
# 9               Ансамблевые методы машинного обучения
# 10  ROS: стань контрибьютором самого большого Open...
# 11  Как количественные исследования помогают созда...
# 12                        Как собрать свой Lighthouse
# 13  [Личный опыт] Жизнь и IT в Сеуле: почему жить ...
# 14  Использование паттерна BFF для создания общих ...
# 15                 Миграция с Terraform на Terragrunt
# 16            Разбираем обфусцированный CrackMe на C#
# 17  Лучшие RP2040 платы для ваших проектов в 2021 ...
# 18  Как совместить поездку на конференцию и семейн...
# 19  Всё о работе с cookie в Python — класс http.co...
# 20  Приглашаем в онлайн-школу Open Source-разработ...
# 21                Гайд по использованию enum в Python
# 22        Начинал строить дома, построил карьеру в IT
# 23             Как сделать магический шар на Three.js
# 24            Еще один сайт для изучения слов. Зачем?
# 25  Marshmallow vs. Pydantic: две лучшие библиотек...
# 26    Greybox-фаззинг: level up. Как улучшали фаззеры
# 27  Do IT like a Russian: чем крупный ритейл может...
# 28  Структурная нота: кому — вершки, а кому — коре...
# 29  Почему у нас такое жёсткое лицензионное соглаш...
# 30                          BDD-тестирование чат-бота
# 31  Clickhouse рядом с Zabbix или чем собирать лог...
# 32  Киберпанк, который мы заслужили, или как Prism...
# 33  Обзор Codelobster — Удобная кроссплатформенная...
# 34  Infrastructure as code: обзор опенсорсных инст...
# 35   Профессионально обрабатываем исключения в Python
# 36               От мюонного соленоида к Data Science
# 37  Нейродайджест: главное из области машинного об...
# 38           Property-based тестирование с QuickCheck
#
#                                                  link  \
# 0                    https://habr.com/ru/post/571428/
# 1    https://habr.com/ru/company/samsung/blog/571404/
# 2   https://habr.com/ru/company/habr_career/blog/5...
# 3   https://habr.com/ru/company/it_people/blog/571...
# 4                    https://habr.com/ru/post/571342/
# 5                    https://habr.com/ru/post/571344/
# 6   https://habr.com/ru/company/alconost/blog/571366/
# 7   https://habr.com/ru/company/skillfactory/blog/...
# 8       https://habr.com/ru/company/otus/blog/571286/
# 9                    https://habr.com/ru/post/571296/
# 10   https://habr.com/ru/company/samsung/blog/571302/
# 11  https://habr.com/ru/company/ncloudtech/blog/56...
# 12  https://habr.com/ru/company/oleg-bunin/blog/57...
# 13       https://habr.com/ru/company/gms/blog/571234/
# 14    https://habr.com/ru/company/itsoft/blog/571004/
# 15  https://habr.com/ru/company/southbridge/blog/5...
# 16                   https://habr.com/ru/post/571134/
# 17  https://habr.com/ru/company/selectel/blog/570018/
# 18  https://habr.com/ru/company/it_people/blog/571...
# 19   https://habr.com/ru/company/timeweb/blog/564620/
# 20   https://habr.com/ru/company/samsung/blog/570952/
# 21   https://habr.com/ru/company/timeweb/blog/564826/
# 22    https://habr.com/ru/company/kolesa/blog/571074/
# 23  https://habr.com/ru/company/skillfactory/blog/...
# 24                   https://habr.com/ru/post/570504/
# 25  https://habr.com/ru/company/domclick/blog/570802/
# 26    https://habr.com/ru/company/bizone/blog/570534/
# 27    https://habr.com/ru/company/magnit/blog/570992/
# 28                   https://habr.com/ru/post/570900/
# 29     https://habr.com/ru/company/ruvds/blog/571010/
# 30  https://habr.com/ru/company/oleg-bunin/blog/55...
# 31                   https://habr.com/ru/post/570958/
# 32    https://habr.com/ru/company/prisma/blog/559028/
# 33                   https://habr.com/ru/post/568620/
# 34      https://habr.com/ru/company/otus/blog/570926/
# 35      https://habr.com/ru/company/otus/blog/570882/
# 36  https://habr.com/ru/company/skillfactory/blog/...
# 37                   https://habr.com/ru/post/570912/
# 38  https://habr.com/ru/company/typeable/blog/570922/
#
#                                                  text
# 0   за 3 месяца сразу 2 клиента интерволги (интерн...
# 1   лето подходит к концу, а возможность поработат...
# 2   сегодня в рубрике «где работать в ит» расскаже...
# 3   если спросить опытного питониста в каких компа...
# 4   просидев на одном предприятии несколько лет, я...
# 5   с развитием информационных технологий професси...
# 6   производительность си — в программах на питоне...
# 7   chainmap — инструмент управления поиском в сло...
# 8   mongodb – одна из самых популярных документ-ор...
# 9   ансамблевые методы - это мощный инструмент для...
# 10  источник: https://spectrum.ieee.org/automaton/...
# 11  количественные методы ux-исследований —  такие...
# 12  чем интенсивнее наш feature delivering, тем бы...
# 13  недавно мы рассказывали о жизни разработчика в...
# 14  \r\nконтракт между бэкендным сервисом и фронте...
# 15  https://miro.medium.com/max/700/1*fnd69vqapyso...
# 16  имеется файл crackme, при запуске которого пре...
# 17  \n\r\nв январе 2021 года raspberry foundation ...
# 18  мы (it-people) уже 11 лет проводим конференции...
# 19   \nмодуль http.cookies реализует парсер для co...
# 20  открытое программное обеспечение (open source ...
# 21  \nмодуль enum содержит в себе тип для перечисл...
# 22  часто слышу мнение, что для работы программист...
# 23  анимированный объём при помощи встроенного шей...
# 24  я пробовал anki, cram, memrise, drops, quizlet...
# 25  сериализация и десериализация данных — это пре...
# 26  \nавтор: иннокентий сенновский \nв предыдущей ...
# 27  привет! меня зовут валентин щитов, я cio компа...
# 28  лирическое вступлениекадр из мультфильма 1974 ...
# 29  \n\nпервый конфликт — в том, чтобы дать клиент...
# 30  многие знакомы с методологией test-driven deve...
# 31  если вы используете zabbix для мониторинга ваш...
# 32  привет, хабр! я миша, r&d инженер в prisma lab...
# 33  раньше, когда еще не было ни phpstorm-а, ни vs...
# 34  давайте взглянем на текущее положение вещей в ...
# 35  одним из недостатков гибких языков, таких как ...
# 36  компактный мюонный соленоид в пещереавтор стат...
# 37  новый язык программирования от open ai, рост п...
# 38  автор статьи: klntsky \n\nчто такое property-b...

# %%
# Pages 11-19
get_news_table(get_all_links(list_urls))
# Out:
#                         date  \
# 0  2021-08-02 10:14:52+00:00
# 1  2021-08-02 12:03:46+00:00
# 2  2021-08-02 11:22:06+00:00
# 3  2021-08-02 09:13:04+00:00
# 4  2021-08-02 06:58:01+00:00
# 5  2021-08-02 07:00:02+00:00
# 6  2021-08-01 16:24:05+00:00
# 7  2021-08-01 17:48:35+00:00
# 8  2021-08-01 11:12:39+00:00
# 9  2021-08-01 17:34:10+00:00
# 10 2021-07-31 11:31:48+00:00
# 11 2021-07-31 18:06:29+00:00
# 12 2021-07-31 15:18:51+00:00
# 13 2021-07-30 13:00:02+00:00
# 14 2021-07-30 14:47:36+00:00
# 15 2021-07-30 14:39:28+00:00
# 16 2021-07-30 10:58:13+00:00
# 17 2021-07-30 08:01:14+00:00
# 18 2021-07-30 08:00:03+00:00
# 19 2021-07-30 10:47:18+00:00
# 20 2021-07-30 06:59:40+00:00
# 21 2021-07-29 17:00:41+00:00
# 22 2021-07-29 14:02:45+00:00
# 23 2021-07-29 16:19:58+00:00
# 24 2021-07-29 12:26:15+00:00
# 25 2021-07-29 10:15:31+00:00
# 26 2021-07-29 09:25:09+00:00
# 27 2021-07-29 10:38:45+00:00
#
#                                                 title  \
# 0   Кратко: запросы к API и разбор XML-ответов. Py...
# 1                Распознавание блюд в кафетерии банка
# 2   Метеостанция на Banana Pi M64 (Linux, C#, Dock...
# 3   Немного про современные технологии Greybox-фаз...
# 4                    10 приниципов разработки на Java
# 5   Еще одна стажировка, или сказ про реверс IP-ка...
# 6   Установка JUNIPER VRR через CLI на гипервизоре...
# 7   FOSS News №81 – дайджест материалов о свободно...
# 8   Когда нужна телеметрия: интегрируем в проект б...
# 9   Чем машинное обучение отличается от статистики...
# 10  [Личный опыт] Лондон: не всегда мечта для прог...
# 11  Три предметно-ориентированных языка программир...
# 12    Tweet-a-pot, или Как я через Twitter кофе варил
# 13      С Днём Сисадмина! А кто его сегодня отмечает?
# 14  Где ещё жить и работать кроме Москвы: четыре г...
# 15    Как перенести нейросеть на мобильное устройство
# 16  13 проектов для Python-программистов уровня in...
# 17           Opensource система умного дома на nodejs
# 18  3 совета для разработчиков по результатам 20 с...
# 19                     Миру нужны фуллстек-крафтсмены
# 20          Выявление самозванцев среди программистов
# 21  Быстрое и точное обнаружение аномалий по копул...
# 22     Архитектура веб-проекта для тяжелых вычислений
# 23  Как я прошёл путь от инженера-автоматизатора P...
# 24                           Микросервисы vs. Монолит
# 25  Как автоматизировать администрирование Hadoop,...
# 26  Оценка RISC-ов: когда ожидать серверы на ARM в...
# 27                      DataScience Digest — 29.07.21
#
#                                                  link  \
# 0                    https://habr.com/ru/post/570852/
# 1       https://habr.com/ru/company/alfa/blog/569208/
# 2    https://habr.com/ru/company/timeweb/blog/569748/
# 3     https://habr.com/ru/company/bizone/blog/570312/
# 4                    https://habr.com/ru/post/570654/
# 5   https://habr.com/ru/company/ntc-vulkan/blog/56...
# 6                    https://habr.com/ru/post/570752/
# 7                    https://habr.com/ru/post/570764/
# 8                    https://habr.com/ru/post/570720/
# 9   https://habr.com/ru/company/skillfactory/blog/...
# 10       https://habr.com/ru/company/gms/blog/570652/
# 11  https://habr.com/ru/company/audiomania/blog/57...
# 12  https://habr.com/ru/company/skillfactory/blog/...
# 13     https://habr.com/ru/company/ruvds/blog/570418/
# 14   https://habr.com/ru/company/headzio/blog/570506/
# 15                   https://habr.com/ru/post/570052/
# 16  https://habr.com/ru/company/skillbox/blog/570472/
# 17                   https://habr.com/ru/post/570432/
# 18                   https://habr.com/ru/post/570430/
# 19     https://habr.com/ru/company/jugru/blog/558702/
# 20                   https://habr.com/ru/post/570198/
# 21      https://habr.com/ru/company/otus/blog/570314/
# 22                   https://habr.com/ru/post/570328/
# 23  https://habr.com/ru/company/skillfactory/blog/...
# 24  https://habr.com/ru/company/yandex_praktikum/b...
# 25    https://habr.com/ru/company/ru_mts/blog/569762/
# 26  https://habr.com/ru/company/selectel/blog/570050/
# 27                   https://habr.com/ru/post/570272/
#
#                                                  text
# 0   этот пост предназначен в первую очередь для но...
# 1   в кафетерии альфа-банка в обеденный час-пик об...
# 2   \n\r\nстатей о создании метеостанции на базе a...
# 3   \nавтор: иннокентий сенновский\nкак найти баги...
# 4   сколько раз вы были в ситуации, когда вы хотел...
# 5   вступлениеитак, меня взяли на стажировку. стаж...
# 6   в определенный момент домашняя лаба (бесшумная...
# 7   \n\nвсем привет!\nпродолжаем дайджесты новосте...
# 8   два сигнала телеметрии, формируемые в микрокон...
# 9   к старту курса о машинном и глубоком обучении ...
# 10  анатолий бардуков работал в «яндексе», улучшая...
# 11  в прошлый раз мы рассказывали о книгах, которы...
# 12  мы уже писали о том, как сделать умный термост...
# 13  профессию сисадмина пытались забыть несколько ...
# 14  в москве есть практически всё: есть где порабо...
# 15  в статье поговорим как обучить несложную cnn с...
# 16  изучение основ python — прекрасный опыт. но эй...
# 17  интерфейс главного менюпривет, хабр! хочу поде...
# 18  на глаза попалась статья о приеме разработчико...
# 19   \nспор «фуллстек против узкой специализации» ...
# 20  кратко о себе. работаю в центральном аппарате ...
# 21  выбросы или аномалии – это точки данных, котор...
# 22  one ring to rule them allj. r. r. tolkien «the...
# 23  в этом материале, переводом которого мы делимс...
# 24  в начале ноября на ютуб-канале яндекс.практику...
# 25  привет, хабр! меня зовут александр черёмухин, ...
# 26  \r\nигнорировать влияние arm-архитектуры на ры...
# 27  встречайте свежий выпуск дайджеста полезных ма...

# %%
# Test for one link

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: `<дата утечки> - <источник утечки> - <описание утечки>`
#
# **Подсказка**: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
import json

# %%
EMAIL = ['xxx@x.ru', 'yyy@y.com']
emails = {
    'emailAddresses' : EMAIL
}

URL = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'

headers = {
    'Vaar-Header-App-Build-Version': '1.0.0', 
    'Vaar-Header-App-Product': 'hackcheck-web-avast',
    'Vaar-Version': '0',
    'Vaar-Header-App-Product-Name': 'hackcheck-web-avast'
}

# %%
request = requests.post(URL, json=emails, headers=headers)
request.json()
# Out:
# {'breaches': {'2': {'breachId': 2,
#    'site': 'linkedin.com',
#    'recordsCount': 158591429,
#    'description': "In 2012, online professional networking platform LinkedIn fell victim to a breach of its members' passwords. Four years later, 117 million email and password combinations from that breach appeared for sale on a dark web marketplace. \n\nThe leaked passwords had only been protected by unsalted SHA-1 cryptographic hashing, which prompted LinkedIn to enforce salted hashing after the breach. Russian national Yevgeniy Nikulin was accused of the breach and was extradited from the Czech Republic to the United States as of March 2018.",
#    'publishDate': '2016-10-21T00:00:00Z',
#    'statistics': {'usernames': 0,
#     'passwords': 111975337,
#     'emails': 158591429}},
#   '3': {'breachId': 3,
#    'site': 'adobe.com',
#    'recordsCount': 152046506,
#    'description': "In October of 2013, criminals penetrated Adobe's corporate network and the stole source code for several of its software products. The affected products included Adobe's ColdFusion web application platform as well as the Acrobat suite of products. Adobe asserts that criminals also accessed nearly three-million customer credit card records and stole login data for an undisclosed number of Adobe user accounts.",
#    'publishDate': '2016-10-21T00:00:00Z',
#    'statistics': {'usernames': 0,
#     'passwords': 129430596,
#     'emails': 152046506}},
#   '12': {'breachId': 12,
#    'site': 'vk.com',
#    'recordsCount': 110121799,
#    'description': "Popular Russian social networking platform VKontakte was breached in late 2012. Over 100 million clear-text passwords were compromised in the breach. Breached credential sets included victims' e-mail addresses, passwords, dates of birth, phone numbers and location details. The credential set was advertised on a dark web marketplace as of June 2016 for a price of one bitcoin. ",
#    'publishDate': '2016-10-29T00:00:00Z',
#    'statistics': {'usernames': 0,
#     'passwords': 107425364,
#     'emails': 104247327}},
#   '15': {'breachId': 15,
#    'site': 'imesh.com',
#    'recordsCount': 50913222,
#    'description': 'In June 2016, a cache of over 51 million user credentials from the online sharing service iMesh appeared for sale on a dark web marketplace.  The database contained user email addresses, usernames, passwords, IP addresses and location.',
#    'publishDate': '2016-10-23T00:00:00Z',
#    'statistics': {'usernames': 50909015,
#     'passwords': 50913222,
#     'emails': 50913222}},
#   '41': {'breachId': 41,
#    'site': 'dropbox.com',
#    'recordsCount': 68591031,
#    'description': "Cloud storage company Dropbox suffered a major data breach in 2012. Criminals leveraged stolen employee login credentials to access a project document containing user email addresses and hashed passwords. Thanks to employees' passwords reuse between work and personal accounts, several matches were exploited, which ultimately lead to the full scope of the breach. It wasn't until August 2016 that Dropbox confirmed over 68 million user credentials had been breached in 2012. In response, DropBox enforced a password reset for its users. ",
#    'publishDate': '2016-10-24T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 68591031, 'emails': 68591031}},
#   '2961': {'breachId': 2961,
#    'site': 'cdprojektred.com',
#    'recordsCount': 1871459,
#    'description': "In March 2016, CDProjektRed.com.com's forum database was breached. The attacker may have exploited a vulnerability in vBulletin. The stolen data contains over 1,870,000 user records including associated usernames, email addresses, hashed passwords, and salts. The leaked credentials are being shared and sold privately on the dark web.",
#    'publishDate': '2017-01-31T00:00:00Z',
#    'statistics': {'usernames': 1871410,
#     'passwords': 1871457,
#     'emails': 1871289}},
#   '3164': {'breachId': 3164,
#    'site': 'cfire.mail.ru',
#    'recordsCount': 12880232,
#    'description': "In July and August of 2016, two criminals carried out attacks on three separate forums hosted by Mail.ru, including CFire. The hackers used known SQL injection vulnerabilities found in older vBulletin forum software to obtain access to the databases. Shortly after the breach itself, the contents of CFire's database were leaked publicly. The database contains usernames, email addresses, and MD5 hashed passwords for just under 13 million users.",
#    'publishDate': '2017-02-14T00:00:00Z',
#    'statistics': {'usernames': 12880232,
#     'passwords': 12880222,
#     'emails': 12845820}},
#   '3176': {'breachId': 3176,
#    'site': 'parapa.mail.ru',
#    'recordsCount': 5029003,
#    'description': "In July and August 2016, two criminals executed attacks against three separate forums hosted by Mail.ru including the Russian forum Parapa. Shortly after the breach occurred, the contents of Parapa's database were leaked publicly. The database contains usernames, email addresses, and hashed passwords for around 5 million users.",
#    'publishDate': '2017-02-14T00:00:00Z',
#    'statistics': {'usernames': 5029000,
#     'passwords': 5029003,
#     'emails': 4941344}},
#   '3520': {'breachId': 3520,
#    'site': 'globalreach.eu',
#    'recordsCount': 921298,
#    'description': "In 2016, Global Reach Technology's database was allegedly breached. The stolen records are being shared among private cirlces on the darknet.",
#    'publishDate': '2017-03-15T00:00:00Z',
#    'statistics': {'usernames': 13492, 'passwords': 921298, 'emails': 907696}},
#   '3587': {'breachId': 3587,
#    'site': 'rayli.com.cn',
#    'recordsCount': 4844179,
#    'description': "On an unconfirmed date, Chinese gossip site Rayli's user database was allegedly breached. The stolen data contains over 4,850,000 records including email addresses, usernames, passwords, and salts. The compromised data is being shared privately among closed and trusted groups.",
#    'publishDate': '2017-03-01T00:00:00Z',
#    'statistics': {'usernames': 4841886,
#     'passwords': 4833694,
#     'emails': 4803135}},
#   '3669': {'breachId': 3669,
#    'site': 'youku.com',
#    'recordsCount': 94244880,
#    'description': 'Youku is a large Chinese video content company whose user database was allegedly breached in 2016. The compromised data later appeared for sale on a dark web marketplace April 2017. The dark web listing advertised the sale of 100M user accounts.',
#    'publishDate': '2017-03-24T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 94238535, 'emails': 94244880}},
#   '13094': {'breachId': 13094,
#    'site': 'myheritage.com',
#    'recordsCount': 110041653,
#    'description': 'In October 2017, a customer database belonging to online genealogy platform MyHeritage was breached. The stolen records included email addresses and SHA-1 hashed passwords, as well as sensitive PII. The data has been sold on at least one dark web market and is also being privately shared amongst several criminal groups.',
#    'publishDate': '2017-11-04T00:00:00Z',
#    'statistics': {'usernames': 0,
#     'passwords': 110041647,
#     'emails': 110041653}},
#   '13662': {'breachId': 13662,
#    'site': 'netlog.com',
#    'recordsCount': 52904632,
#    'description': 'Netlog (formerly known as Facebox and Bingbox) was a Belgian social networking website specifically targeted at the global youth demographic. On Netlog, members could create their own web page, meet new people, chat, play games, share videos and post blogs.\r\n\r\nIn July 2018, Netlog sent out an email informing users registered before December 2012 that there was a security breach of their user database.',
#    'publishDate': '2018-02-18T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 52902665, 'emails': 52904632}},
#   '16768': {'breachId': 16768,
#    'site': 'canva.com',
#    'recordsCount': 137434010,
#    'description': "In May 2019, graphic-design site Canva's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.",
#    'publishDate': '2019-06-13T00:00:00Z',
#    'statistics': {'usernames': 137304104,
#     'passwords': 61348974,
#     'emails': 137402835}},
#   '17009': {'breachId': 17009,
#    'site': 'zynga.com',
#    'recordsCount': 216159495,
#    'description': 'In September 2019, the game developer Zynga was allegedly breached. The stolen data contains usernames, passwords, salts, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2019-10-17T00:00:00Z',
#    'statistics': {'usernames': 214648143,
#     'passwords': 134762791,
#     'emails': 159032663}},
#   '17110': {'breachId': 17110,
#    'site': 'azcentral.com',
#    'recordsCount': 705538,
#    'description': 'At an unconfirmed date, online Arizona newspaper "AZ Central" was allegedly breached. The stolen data contains passwords and email addresses. This breach is being publicly shared on the internet.',
#    'publishDate': '2020-01-03T00:00:00Z',
#    'statistics': {'usernames': 0, 'passwords': 702971, 'emails': 705538}},
#   '17670': {'breachId': 17670,
#    'site': 'wishbone.io',
#    'recordsCount': 37475476,
#    'description': 'In January 2020, the online poll website Wishbone was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2020-05-28T00:00:00Z',
#    'statistics': {'usernames': 31111127,
#     'passwords': 10648734,
#     'emails': 10234249}},
#   '37177': {'breachId': 37177,
#    'site': 'forums.vkmonline.com',
#    'recordsCount': 825654,
#    'description': 'At an unconfirmed date, the Russian-language music forum VKM was allegedly breached. The stolen data contains passwords, IPs, email addresses, usernames and additional personal information. This breach is being privately shared on the internet.',
#    'publishDate': '2021-02-11T00:00:00Z',
#    'statistics': {'usernames': 825566,
#     'passwords': 825654,
#     'emails': 824936}}},
#  'data': {'parapa.mail.ru': {'xxx@x.ru': [{'breachId': 3176,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'adobe.com': {'xxx@x.ru': [{'breachId': 3,
#      'usernameBreached': False,
#      'passwordBreached': True}],
#    'yyy@y.com': [{'breachId': 3,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'cdprojektred.com': {'xxx@x.ru': [{'breachId': 2961,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'azcentral.com': {'yyy@y.com': [{'breachId': 17110,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'linkedin.com': {'yyy@y.com': [{'breachId': 2,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'dropbox.com': {'yyy@y.com': [{'breachId': 41,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'wishbone.io': {'yyy@y.com': [{'breachId': 17670,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'youku.com': {'yyy@y.com': [{'breachId': 3669,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'myheritage.com': {'yyy@y.com': [{'breachId': 13094,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'rayli.com.cn': {'yyy@y.com': [{'breachId': 3587,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'canva.com': {'yyy@y.com': [{'breachId': 16768,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'globalreach.eu': {'yyy@y.com': [{'breachId': 3520,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'cfire.mail.ru': {'xxx@x.ru': [{'breachId': 3164,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'vk.com': {'xxx@x.ru': [{'breachId': 12,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'forums.vkmonline.com': {'yyy@y.com': [{'breachId': 37177,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'netlog.com': {'yyy@y.com': [{'breachId': 13662,
#      'usernameBreached': False,
#      'passwordBreached': True}]},
#   'imesh.com': {'xxx@x.ru': [{'breachId': 15,
#      'usernameBreached': True,
#      'passwordBreached': True}],
#    'yyy@y.com': [{'breachId': 15,
#      'usernameBreached': True,
#      'passwordBreached': True}]},
#   'zynga.com': {'yyy@y.com': [{'breachId': 17009,
#      'usernameBreached': True,
#      'passwordBreached': False}]}},
#  'summary': {'xxx@x.ru': {'breaches': [3, 12, 15, 2961, 3164, 3176]},
#   'yyy@y.com': {'breaches': [2,
#     3,
#     15,
#     41,
#     3520,
#     3587,
#     3669,
#     13094,
#     13662,
#     16768,
#     17009,
#     17110,
#     17670,
#     37177]}}}

# %%
# Не хватает 2х утечек?! утечки по обоим мейлам на сайтах - adobe.com, imesh.com

breaches = pd.DataFrame(request.json()['breaches']).T.reset_index()

# %%
breaches[['publishDate', 'site', 'description']]
# Out:
#              publishDate                  site  \
# 0   2016-10-21T00:00:00Z          linkedin.com
# 1   2016-10-21T00:00:00Z             adobe.com
# 2   2016-10-29T00:00:00Z                vk.com
# 3   2016-10-23T00:00:00Z             imesh.com
# 4   2016-10-24T00:00:00Z           dropbox.com
# 5   2017-01-31T00:00:00Z      cdprojektred.com
# 6   2017-02-14T00:00:00Z         cfire.mail.ru
# 7   2017-02-14T00:00:00Z        parapa.mail.ru
# 8   2017-03-15T00:00:00Z        globalreach.eu
# 9   2017-03-01T00:00:00Z          rayli.com.cn
# 10  2017-03-24T00:00:00Z             youku.com
# 11  2017-11-04T00:00:00Z        myheritage.com
# 12  2018-02-18T00:00:00Z            netlog.com
# 13  2019-06-13T00:00:00Z             canva.com
# 14  2019-10-17T00:00:00Z             zynga.com
# 15  2020-01-03T00:00:00Z         azcentral.com
# 16  2020-05-28T00:00:00Z           wishbone.io
# 17  2021-02-11T00:00:00Z  forums.vkmonline.com
#
#                                           description
# 0   In 2012, online professional networking platfo...
# 1   In October of 2013, criminals penetrated Adobe...
# 2   Popular Russian social networking platform VKo...
# 3   In June 2016, a cache of over 51 million user ...
# 4   Cloud storage company Dropbox suffered a major...
# 5   In March 2016, CDProjektRed.com.com's forum da...
# 6   In July and August of 2016, two criminals carr...
# 7   In July and August 2016, two criminals execute...
# 8   In 2016, Global Reach Technology's database wa...
# 9   On an unconfirmed date, Chinese gossip site Ra...
# 10  Youku is a large Chinese video content company...
# 11  In October 2017, a customer database belonging...
# 12  Netlog (formerly known as Facebox and Bingbox)...
# 13  In May 2019, graphic-design site Canva's datab...
# 14  In September 2019, the game developer Zynga wa...
# 15  At an unconfirmed date, online Arizona newspap...
# 16  In January 2020, the online poll website Wishb...
# 17  At an unconfirmed date, the Russian-language m...

# %%
# В breaches хранится сайт на кот. произошла утечка, время утечки и описание

breaches = request.json()['breaches']
breaches
# Out:
# {'2': {'breachId': 2,
#   'site': 'linkedin.com',
#   'recordsCount': 158591429,
#   'description': "In 2012, online professional networking platform LinkedIn fell victim to a breach of its members' passwords. Four years later, 117 million email and password combinations from that breach appeared for sale on a dark web marketplace. \n\nThe leaked passwords had only been protected by unsalted SHA-1 cryptographic hashing, which prompted LinkedIn to enforce salted hashing after the breach. Russian national Yevgeniy Nikulin was accused of the breach and was extradited from the Czech Republic to the United States as of March 2018.",
#   'publishDate': '2016-10-21T00:00:00Z',
#   'statistics': {'usernames': 0, 'passwords': 111975337, 'emails': 158591429}},
#  '3': {'breachId': 3,
#   'site': 'adobe.com',
#   'recordsCount': 152046506,
#   'description': "In October of 2013, criminals penetrated Adobe's corporate network and the stole source code for several of its software products. The affected products included Adobe's ColdFusion web application platform as well as the Acrobat suite of products. Adobe asserts that criminals also accessed nearly three-million customer credit card records and stole login data for an undisclosed number of Adobe user accounts.",
#   'publishDate': '2016-10-21T00:00:00Z',
#   'statistics': {'usernames': 0, 'passwords': 129430596, 'emails': 152046506}},
#  '12': {'breachId': 12,
#   'site': 'vk.com',
#   'recordsCount': 110121799,
#   'description': "Popular Russian social networking platform VKontakte was breached in late 2012. Over 100 million clear-text passwords were compromised in the breach. Breached credential sets included victims' e-mail addresses, passwords, dates of birth, phone numbers and location details. The credential set was advertised on a dark web marketplace as of June 2016 for a price of one bitcoin. ",
#   'publishDate': '2016-10-29T00:00:00Z',
#   'statistics': {'usernames': 0, 'passwords': 107425364, 'emails': 104247327}},
#  '15': {'breachId': 15,
#   'site': 'imesh.com',
#   'recordsCount': 50913222,
#   'description': 'In June 2016, a cache of over 51 million user credentials from the online sharing service iMesh appeared for sale on a dark web marketplace.  The database contained user email addresses, usernames, passwords, IP addresses and location.',
#   'publishDate': '2016-10-23T00:00:00Z',
#   'statistics': {'usernames': 50909015,
#    'passwords': 50913222,
#    'emails': 50913222}},
#  '41': {'breachId': 41,
#   'site': 'dropbox.com',
#   'recordsCount': 68591031,
#   'description': "Cloud storage company Dropbox suffered a major data breach in 2012. Criminals leveraged stolen employee login credentials to access a project document containing user email addresses and hashed passwords. Thanks to employees' passwords reuse between work and personal accounts, several matches were exploited, which ultimately lead to the full scope of the breach. It wasn't until August 2016 that Dropbox confirmed over 68 million user credentials had been breached in 2012. In response, DropBox enforced a password reset for its users. ",
#   'publishDate': '2016-10-24T00:00:00Z',
#   'statistics': {'usernames': 0, 'passwords': 68591031, 'emails': 68591031}},
#  '2961': {'breachId': 2961,
#   'site': 'cdprojektred.com',
#   'recordsCount': 1871459,
#   'description': "In March 2016, CDProjektRed.com.com's forum database was breached. The attacker may have exploited a vulnerability in vBulletin. The stolen data contains over 1,870,000 user records including associated usernames, email addresses, hashed passwords, and salts. The leaked credentials are being shared and sold privately on the dark web.",
#   'publishDate': '2017-01-31T00:00:00Z',
#   'statistics': {'usernames': 1871410,
#    'passwords': 1871457,
#    'emails': 1871289}},
#  '3164': {'breachId': 3164,
#   'site': 'cfire.mail.ru',
#   'recordsCount': 12880232,
#   'description': "In July and August of 2016, two criminals carried out attacks on three separate forums hosted by Mail.ru, including CFire. The hackers used known SQL injection vulnerabilities found in older vBulletin forum software to obtain access to the databases. Shortly after the breach itself, the contents of CFire's database were leaked publicly. The database contains usernames, email addresses, and MD5 hashed passwords for just under 13 million users.",
#   'publishDate': '2017-02-14T00:00:00Z',
#   'statistics': {'usernames': 12880232,
#    'passwords': 12880222,
#    'emails': 12845820}},
#  '3176': {'breachId': 3176,
#   'site': 'parapa.mail.ru',
#   'recordsCount': 5029003,
#   'description': "In July and August 2016, two criminals executed attacks against three separate forums hosted by Mail.ru including the Russian forum Parapa. Shortly after the breach occurred, the contents of Parapa's database were leaked publicly. The database contains usernames, email addresses, and hashed passwords for around 5 million users.",
#   'publishDate': '2017-02-14T00:00:00Z',
#   'statistics': {'usernames': 5029000,
#    'passwords': 5029003,
#    'emails': 4941344}},
#  '3520': {'breachId': 3520,
#   'site': 'globalreach.eu',
#   'recordsCount': 921298,
#   'description': "In 2016, Global Reach Technology's database was allegedly breached. The stolen records are being shared among private cirlces on the darknet.",
#   'publishDate': '2017-03-15T00:00:00Z',
#   'statistics': {'usernames': 13492, 'passwords': 921298, 'emails': 907696}},
#  '3587': {'breachId': 3587,
#   'site': 'rayli.com.cn',
#   'recordsCount': 4844179,
#   'description': "On an unconfirmed date, Chinese gossip site Rayli's user database was allegedly breached. The stolen data contains over 4,850,000 records including email addresses, usernames, passwords, and salts. The compromised data is being shared privately among closed and trusted groups.",
#   'publishDate': '2017-03-01T00:00:00Z',
#   'statistics': {'usernames': 4841886,
#    'passwords': 4833694,
#    'emails': 4803135}},
#  '3669': {'breachId': 3669,
#   'site': 'youku.com',
#   'recordsCount': 94244880,
#   'description': 'Youku is a large Chinese video content company whose user database was allegedly breached in 2016. The compromised data later appeared for sale on a dark web marketplace April 2017. The dark web listing advertised the sale of 100M user accounts.',
#   'publishDate': '2017-03-24T00:00:00Z',
#   'statistics': {'usernames': 0, 'passwords': 94238535, 'emails': 94244880}},
#  '13094': {'breachId': 13094,
#   'site': 'myheritage.com',
#   'recordsCount': 110041653,
#   'description': 'In October 2017, a customer database belonging to online genealogy platform MyHeritage was breached. The stolen records included email addresses and SHA-1 hashed passwords, as well as sensitive PII. The data has been sold on at least one dark web market and is also being privately shared amongst several criminal groups.',
#   'publishDate': '2017-11-04T00:00:00Z',
#   'statistics': {'usernames': 0, 'passwords': 110041647, 'emails': 110041653}},
#  '13662': {'breachId': 13662,
#   'site': 'netlog.com',
#   'recordsCount': 52904632,
#   'description': 'Netlog (formerly known as Facebox and Bingbox) was a Belgian social networking website specifically targeted at the global youth demographic. On Netlog, members could create their own web page, meet new people, chat, play games, share videos and post blogs.\r\n\r\nIn July 2018, Netlog sent out an email informing users registered before December 2012 that there was a security breach of their user database.',
#   'publishDate': '2018-02-18T00:00:00Z',
#   'statistics': {'usernames': 0, 'passwords': 52902665, 'emails': 52904632}},
#  '16768': {'breachId': 16768,
#   'site': 'canva.com',
#   'recordsCount': 137434010,
#   'description': "In May 2019, graphic-design site Canva's database was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.",
#   'publishDate': '2019-06-13T00:00:00Z',
#   'statistics': {'usernames': 137304104,
#    'passwords': 61348974,
#    'emails': 137402835}},
#  '17009': {'breachId': 17009,
#   'site': 'zynga.com',
#   'recordsCount': 216159495,
#   'description': 'In September 2019, the game developer Zynga was allegedly breached. The stolen data contains usernames, passwords, salts, email addresses and additional personal information. This breach is being privately shared on the internet.',
#   'publishDate': '2019-10-17T00:00:00Z',
#   'statistics': {'usernames': 214648143,
#    'passwords': 134762791,
#    'emails': 159032663}},
#  '17110': {'breachId': 17110,
#   'site': 'azcentral.com',
#   'recordsCount': 705538,
#   'description': 'At an unconfirmed date, online Arizona newspaper "AZ Central" was allegedly breached. The stolen data contains passwords and email addresses. This breach is being publicly shared on the internet.',
#   'publishDate': '2020-01-03T00:00:00Z',
#   'statistics': {'usernames': 0, 'passwords': 702971, 'emails': 705538}},
#  '17670': {'breachId': 17670,
#   'site': 'wishbone.io',
#   'recordsCount': 37475476,
#   'description': 'In January 2020, the online poll website Wishbone was allegedly breached. The stolen data contains usernames, passwords, email addresses and additional personal information. This breach is being privately shared on the internet.',
#   'publishDate': '2020-05-28T00:00:00Z',
#   'statistics': {'usernames': 31111127,
#    'passwords': 10648734,
#    'emails': 10234249}},
#  '37177': {'breachId': 37177,
#   'site': 'forums.vkmonline.com',
#   'recordsCount': 825654,
#   'description': 'At an unconfirmed date, the Russian-language music forum VKM was allegedly breached. The stolen data contains passwords, IPs, email addresses, usernames and additional personal information. This breach is being privately shared on the internet.',
#   'publishDate': '2021-02-11T00:00:00Z',
#   'statistics': {'usernames': 825566, 'passwords': 825654, 'emails': 824936}}}

# %%
# нет полезной информации

data = request.json()['data']

# %%
# почта по которой произошла утечка

summary = request.json()['summary']
summary
# Out:
# {'xxx@x.ru': {'breaches': [3, 12, 15, 2961, 3164, 3176]},
#  'yyy@y.com': {'breaches': [2,
#    3,
#    15,
#    41,
#    3520,
#    3587,
#    3669,
#    13094,
#    13662,
#    16768,
#    17009,
#    17110,
#    17670,
#    37177]}}

# %%
leak_df = pd.DataFrame()

for mail, breaches in request.json()['summary'].items():

    for index in breaches['breaches']:
#         print(type(index))
        index = str(index)
        site = request.json()['breaches'][index]['site']
        description = request.json()['breaches'][index]['description']
        date = request.json()['breaches'][index]['publishDate']
        rows = {'mail' : mail, 'date' : date, 'site' : site, 'description' :  description}
        leak_df = pd.concat([leak_df, pd.DataFrame([rows])])
        
leak_df.reset_index(drop=True)
# Out:
#          mail                  date                  site  \
# 0    xxx@x.ru  2016-10-21T00:00:00Z             adobe.com
# 1    xxx@x.ru  2016-10-29T00:00:00Z                vk.com
# 2    xxx@x.ru  2016-10-23T00:00:00Z             imesh.com
# 3    xxx@x.ru  2017-01-31T00:00:00Z      cdprojektred.com
# 4    xxx@x.ru  2017-02-14T00:00:00Z         cfire.mail.ru
# 5    xxx@x.ru  2017-02-14T00:00:00Z        parapa.mail.ru
# 6   yyy@y.com  2016-10-21T00:00:00Z          linkedin.com
# 7   yyy@y.com  2016-10-21T00:00:00Z             adobe.com
# 8   yyy@y.com  2016-10-23T00:00:00Z             imesh.com
# 9   yyy@y.com  2016-10-24T00:00:00Z           dropbox.com
# 10  yyy@y.com  2017-03-15T00:00:00Z        globalreach.eu
# 11  yyy@y.com  2017-03-01T00:00:00Z          rayli.com.cn
# 12  yyy@y.com  2017-03-24T00:00:00Z             youku.com
# 13  yyy@y.com  2017-11-04T00:00:00Z        myheritage.com
# 14  yyy@y.com  2018-02-18T00:00:00Z            netlog.com
# 15  yyy@y.com  2019-06-13T00:00:00Z             canva.com
# 16  yyy@y.com  2019-10-17T00:00:00Z             zynga.com
# 17  yyy@y.com  2020-01-03T00:00:00Z         azcentral.com
# 18  yyy@y.com  2020-05-28T00:00:00Z           wishbone.io
# 19  yyy@y.com  2021-02-11T00:00:00Z  forums.vkmonline.com
#
#                                           description
# 0   In October of 2013, criminals penetrated Adobe...
# 1   Popular Russian social networking platform VKo...
# 2   In June 2016, a cache of over 51 million user ...
# 3   In March 2016, CDProjektRed.com.com's forum da...
# 4   In July and August of 2016, two criminals carr...
# 5   In July and August 2016, two criminals execute...
# 6   In 2012, online professional networking platfo...
# 7   In October of 2013, criminals penetrated Adobe...
# 8   In June 2016, a cache of over 51 million user ...
# 9   Cloud storage company Dropbox suffered a major...
# 10  In 2016, Global Reach Technology's database wa...
# 11  On an unconfirmed date, Chinese gossip site Ra...
# 12  Youku is a large Chinese video content company...
# 13  In October 2017, a customer database belonging...
# 14  Netlog (formerly known as Facebox and Bingbox)...
# 15  In May 2019, graphic-design site Canva's datab...
# 16  In September 2019, the game developer Zynga wa...
# 17  At an unconfirmed date, online Arizona newspap...
# 18  In January 2020, the online poll website Wishb...
# 19  At an unconfirmed date, the Russian-language m...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)
# ```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: `<дата поста> - <текст поста>`

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
